# %% [markdown]
# <a href="https://colab.research.google.com/github/Fer-2022/CURSO-FES-/blob/main/CLASE_3%2C_EJERCICIOS_Y_CONDICIONALES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#EJERCICIO, CALCULO DE PROMEDIO

#Entrado de datos

Calificacion1= float(input("Ingrese el valor de la calificacion 1er parcial:"))
Calificacion2= float(input("Ingrese el valor de la calificacion 2do parcial:"))
Calificacion3= float(input("Ingrese el valor de la calificacion 3er parcial:"))

promedio= (Calificacion1 + Calificacion2 + Calificacion3) / 3

print("Tu promedio es igual a=", promedio)
# Out:
# Ingrese el valor de la calificacion 1er parcial:5
# Ingrese el valor de la calificacion 2do parcial:10
# Ingrese el valor de la calificacion 3er parcial:3
# Tu promedio es igual a= 6.0

# %%
import math

radio = float(input("radio ->"))

area= math.pi * radio**2
longitud= 2* math.pi * radio

print(f"El area es: {area: .3f}") #.2f es para indicar 2 decimales
print(f"La longitud de la circunferencia es: {longitud: .3f}")
# Out:
# radio ->6
# El area es:  113.097
# La longitud de la circunferencia es:  37.699

# %% [markdown]
# ![Imagen de WhatsApp 2025-06-15 a las 20.38.50_6d535462.jpg](data:image/jpeg;base64,...)

# %%
#FORMULA GENERAL

#ENTRADA DE DATOS

a=float(input("Digita el valor de a:"))
b=float(input("Digita el valor de b:"))
c=float(input("Digita el valor de c:"))



x1= ((- b + pow (pow(b, 2) - (4 *a *c), 1/2))) / (2 * a)
x2= ((- b - pow (pow(b, 2) - (4 *a *c), 1/2))) / (2 * a)



print("El valor de X1 es igual a:", x1)
print("El valor de X2 es igual a:", x2)
# Out:
# Digita el valor de a:1
# Digita el valor de b:7
# Digita el valor de c:12
# El valor de X1 es igual a: -3.0
# El valor de X2 es igual a: -4.0

# %%
import math

a=float(input("Digita el valor de a:"))
b=float(input("Digita el valor de b:"))
c=float(input("Digita el valor de c:"))

#Calcular el discriminate
discriminante = b**2 - 4*a*c

raiz1= (-b + math.sqrt(discriminante)) / (2*a)
raiz2= (-b - math.sqrt(discriminante)) / (2*a)

print(f"Las soluciones de la ecuacion son: {raiz1} y {raiz2}")
# Out:
# Digita el valor de a:1
# Digita el valor de b:7
# Digita el valor de c:12
# Las soluciones de la ecuacion son: -3.0 y -4.0

# %%
#Condicionales

#if, elif, else

numero= int(input("Digite un numero: "))

if numero >0:
    print("El numero es positivo")
elif numero == 0:
    print("El numero es cero")
else:
    print("El numero es negativo")
# Out:
# Digite un numero: 0
# El numero es cero

# %%
#EJERCICIO, CALCULO DE PROMEDIO

#Entrado de datos

Calificacion1= float(input("Ingrese el valor de la calificacion 1er parcial:"))
Calificacion2= float(input("Ingrese el valor de la calificacion 2do parcial:"))
Calificacion3= float(input("Ingrese el valor de la calificacion 3er parcial:"))

promedio= (Calificacion1 + Calificacion2 + Calificacion3) / 3

print("Tu promedio es igual a=", promedio)


#Evaluacion CON IF-ELIF-ELSE

if promedio >= 6 and promedio <=10:
    print("USTED HA APROBADO ")
elif promedio >= 0 and promedio <6:
    print("USTED HA REPROBADO")
else:
    print("INGRESE UNA CALIFICACION VALIDA (ENTRE 0 Y 10)")
# Out:
# Ingrese el valor de la calificacion 1er parcial:8
# Ingrese el valor de la calificacion 2do parcial:10
# Ingrese el valor de la calificacion 3er parcial:9
# Tu promedio es igual a= 9.0
# USTED HA APROBADO
