# %% [markdown]
# <a href="https://colab.research.google.com/github/Fer-2022/CURSO-FES-/blob/main/SEGUNDA_CLASE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola Mundo\n  Mi nombre es Fernando")
# Out:
# Hola Mundo
#   Mi nombre es Fernando

# %% [markdown]
# Enteros: Representan números enteros, positivos o negativos. Por ejemplo, 10, 0 y -5 son enteros.
#
# Flotantes: Representan números decimales. Por ejemplo, 3.14, 0.0 y -2.5 son flotantes.
#
# Cadenas: Representan una serie de caracteres. Por ejemplo, ‘Hola mundo’ y ‘1234’ son cadenas.
#
# Booleanos: Representan valores verdadero o falso. El valor verdadero se representa con True y el valor falso con False

# %%
Numero=1.8
print(Numero)
print(type(Numero))


Cadena= "Fernando"
print(Cadena)
print(type(Cadena))


Valor= False
print(Valor)
print(type(Valor))
# Out:
# 1.8
# <class 'float'>
# Fernando
# <class 'str'>
# False
# <class 'bool'>

# %%
N1= 6
N2= 10
Suma=N1 + N2
Resta=N1 - N2
Division= N1 / N2
Multiplicacion= N1 * N2 # * Se utiliza para multiplicar
Operacion= (N1 * N2) + (N1 / N2)
Potencia= N1 ** 2 # Se utiliza para las potencias

print("El valor de la operacion es igual a:", Potencia)
# Out:
# El valor de la operacion es igual a: 36

# %%
#Operadores Aritmeticos

a= 2
b= 4

resultado= a/b
print(resultado)
# Out:
# 0.5

# %%
#Modulo "Residuo de la division"

a= 10
b= 3

resultado= a % b
print(resultado)
# Out:
# 1

# %%
import numpy as np #Libreria para calcular raices

a= np.sqrt(25)
print(a)
# Out:
# 5.0

# %%
a= 25**0.5
print(a)
# Out:
# 5.0

# %% [markdown]
# ![Imagen de WhatsApp 2025-06-11 a las 19.30.52_f195d51c.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Jerarquia de Operaciones

#Parentesis, Potencias y raices


resultado= ((15 - 13) * (31 - 26) ) + 18 // (1 + 4 * 2)

print("El resutaldo de la operacion es igual a:", resultado)
# Out:
# El resutaldo de la operacion es igual a: 12

# %% [markdown]
# OPERADORES RELACIONALES
#
#
# ![image.png](data:image/png;base64,...)

# %%
#Operadores relacionales

a= 10
b= 5
c= 6

Operacion= (a + c) < b

print(Operacion)
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Operadores logicos

a= 10
b= 15
c= 20

resultado= not((a>b) or (b<c))
print(resultado)
# Out:
# False

# %%
#Operadores de asignacion

a= 1

a += 3 #asignacion suma
a -= 1
a *= 3
a **= 2

print(a)
# Out:
# 81

# %%
#Salida de datos

Nombre= "Fernando"
Altura= 1.75

print("Tu nombre es:", Nombre)
print("Tu Altura es:", Altura)

#Utilizamos format
#print("Tu nombre es: {} y tu Altura es: {}".format(Nombre, Altura))

#ESTA ES LA QUE UTILIZAREMOS
#print(f"Tu nombre es: {Nombre} y tu Altura es: {Altura} metros")

#print(f"Hola: {Nombre} tu Altura es: {Altura} metros")
# Out:
# Tu nombre es: Fernando
# Tu Altura es: 1.75

# %%
#Entrado de datos

#input es una funciom que se utiliza para pedir datos al usuario
nombre= input("Digite su nombre")

print(f"Buenas noches {nombre}")
# Out:
# Digite su nombre Fer
# Buenas noches  Fer

# %%
numero= float(input("Digite un numero: "))

print(f"El numero es {numero *5}")
# Out:
# Digite un numero: 5.5
# El numero es 27.5

# %%
#Funciones integradas

#Convertir de valor numerico a cadena
#n= str(10)
#print(n)

#de enteros a binarios
#n= bin(10)
#print(n)

#n= abs(10)
#print(n)

n= len("Fernando Calderon")
print(n)
# Out:
# 17

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Programa para sumar los primeros N números naturales sin usar condicionales

# Solicitar al usuario el número hasta donde desea sumar
n = int(input("¿Hasta qué número natural quieres sumar? "))

# Calcular la suma con la fórmula N(N + 1) / 2
suma = n * (n + 1) // 2  # División entera para obtener un número entero

# Mostrar el resultado
print(f"La suma de los primeros {n} números naturales es: {suma}")
# Out:
# ¿Hasta qué número natural quieres sumar? 100
# La suma de los primeros 100 números naturales es: 5050
